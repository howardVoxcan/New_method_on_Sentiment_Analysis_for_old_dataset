# %%
pip install underthesea
# Out:
# Requirement already satisfied: underthesea in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (6.8.4)
# Requirement already satisfied: Click>=6.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from underthesea) (8.1.8)
# Requirement already satisfied: python-crfsuite>=0.9.6 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from underthesea) (0.9.11)
# Requirement already satisfied: nltk in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from underthesea) (3.9.1)
# Requirement already satisfied: tqdm in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from underthesea) (4.67.1)
# Requirement already satisfied: requests in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from underthesea) (2.32.3)
# Requirement already satisfied: joblib in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from underthesea) (1.4.2)
# Requirement already satisfied: scikit-learn in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from underthesea) (1.5.2)
# Requirement already satisfied: PyYAML in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from underthesea) (6.0.2)
# Requirement already satisfied: underthesea-core==1.0.4 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from underthesea) (1.0.4)
# Requirement already satisfied: colorama in c:\users\admin\appdata\roaming\python\python310\site-packages (from Click>=6.0->underthesea) (0.4.6)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from nltk->underthesea) (2024.11.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from requests->underthesea) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from requests->underthesea) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from requests->underthesea) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from requests->underthesea) (2024.2.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->underthesea) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->underthesea) (1.14.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->underthesea) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import re
from underthesea import text_normalize, word_tokenize

# %%
df_train=pd.read_csv('./ViCTSD_train.csv')
df_dev=pd.read_csv('./ViCTSD_valid.csv')
df_test=pd.read_csv('./ViCTSD_test.csv')

# %%
df_train
# Out:
#       Unnamed: 0                                            Comment  \
# 0           6326                               Thật tuyệt vời...!!!
# 1           7835  mỹ đã tuột dốc quá nhiều rồi, giờ muốn vực dậy...
# 2           4690  tôi thấy người lái xe hơi bấm còi mới là người...
# 3           6011  Coi dịch là giặc. Đã mang tên đó mà xâm nhập V...
# 4           9303  Thương các bé quá! Các con còn quá nhỏ mà đã p...
# ...          ...                                                ...
# 6995        9296  đọc tin mà đau lòng quá,thảm nạn cứ xãy ra hoà...
# 6996        3645  Nên mua bạn nhé. Để bảo vệ sức khỏe bạn trong ...
# 6997        5008  Nên ra luật người sử dụng ma túy cũng phạm tội...
# 6998        4343  Mua Fadil đủ lăn bánh. Nếu thấy đắt thì đi Mor...
# 6999        5203            2 kẻ này phải xử lý mạnh. Thật căm phẫn
#
#       Constructiveness  Toxicity  \
# 0                    0         0
# 1                    1         0
# 2                    1         1
# 3                    0         0
# 4                    0         0
# ...                ...       ...
# 6995                 0         0
# 6996                 1         0
# 6997                 1         0
# 6998                 1         0
# 6999                 0         1
#
#                                                   Title      Topic
# 0     Những 'bước tiến diệu kỳ' của Trúc Nhi - Diệu Nhi    SucKhoe
# 1     Hình tượng Mỹ sụp đổ trong lòng người dân thế ...    TheGioi
# 2            Cả trăm người đạp xe thể dục bịt kín đường   OtoXemay
# 3                11 ngày không lây nhiễm nCoV cộng đồng    SucKhoe
# 4                               5 trẻ chết đuối dưới ao     ThoiSu
# ...                                                 ...        ...
# 6995                            5 trẻ chết đuối dưới ao     ThoiSu
# 6996    Chưa lập gia đình có nên mua bảo hiểm nhân thọ?  KinhDoanh
# 6997         102 người dương tính ma túy trong quán bar   PhapLuat
# 6998              450 triệu mua xe gì phục vụ gia đình?   OtoXemay
# 6999             5 cháu bé bị mẹ và cậu chăn dắt ăn xin   PhapLuat
#
# [7000 rows x 6 columns]

# %%
for df in [df_train, df_dev, df_test]:
    if 'Comment' in df.columns:
        df.rename(columns={'Comment': 'content'}, inplace=True)

# %%
df_misspell = pd.read_csv('./vietnamese-misspell.csv')
misspell_dict = dict(zip(df_misspell['wrong'], df_misspell['right']))

# %%
emoticon_dict = {
    ":)": "☺️",
    ":))": "☺️",
    ":)))": "☺️",
    "=))": "😄",
    "=)": "😄",
    ":D": "😀",
    ":DD": "😁",
    ":<": "😞",
    ":(": "☹️",
    ":'(": "😢",
    ":'(": "😢",
    ":')": "😂",
    ":')": "😂",
    "<3": "❤️",
    "</3": "💔",
    ":P": "😛",
    ":p": "😛",
    ":O": "😲",
    ":o": "😲",
    ";)": "😉",
    ";-)": "😉",
    ":3": "😺",
    ":^)": "😊",
    "^_^": "😊",
    "-_-": "😑",
    ">_<": "😣",
    "XD": "😆",
    "xD": "😆",
    "T_T": "😭",
    ";_;": "😭",
    ":|": "😐",
    ":/": "😕",
    ":-/": "😕",
    ":-\\": "😕",
    ":'D": "😆",
    ":'D": "😆",
    ":-*": "😘",
    ":*": "😘",
    "<<": "😓",
    ">_>": "😒",
    "<_<": "😒",
    "^\\^": "😆",
    "\\^_^/": "🎉",
    "*^_^*": "🎉",
    "\\o/": "🙌",
    "\\O/": "🙌",
    "O_O": "😳",
    "o_o": "😳",
    ">:O": "😠",
    "^^": "☺️"
}

# %%
def standardize_emoticon(text):
    # Gộp các chuỗi emoticon thường gặp về chuẩn (gộp lặp, ví dụ ^^ ^^ ^^ -> ^^)
    # Gộp emoticon kiểu :) về 1
    text = re.sub(r'((:\)+))', ':)', text)
    text = re.sub(r'((=\)+))', '=)', text)
    text = re.sub(r'((\^_?\^)+)', '^^', text)        # ^^, ^_^, ^^ ^^, ...
    text = re.sub(r'(<3+)', '<3', text)
    text = re.sub(r'(\)+)', ')', text)
    text = re.sub(r'(\(+)', '(', text)
    # Gộp mọi chuỗi ^^ liên tiếp về 1 ^^ (kể cả có cách ra)
    text = re.sub(r'(\^\^)(\s+\^\^)+', '^^', text)
    # Gộp ((
    text = re.sub(r'(\(+)', '(', text)
    text = re.sub(r'(\)+)', ')', text)
    return text

# %%
def convert_emoticon(text, emoticon_dict):
    # Duyệt emoticon dài trước
    for emo in sorted(emoticon_dict, key=len, reverse=True):
        # Chỉ thay thế khi là nguyên một cụm (dùng word boundary nếu cần)
        text = re.sub(re.escape(emo) + r'(?=\s|$)', emoticon_dict[emo], text)
    return text

# %%
def standardize_word(text, misspell_dict):
    # Gộp ký tự kéo dài (đẹpppp -> đẹp)
    text = re.sub(r'(\w)\1{2,}', r'\1', text)
    # Chuẩn hóa chính tả/viết tắt
    for wrong, right in misspell_dict.items():
        text = re.sub(r'\b' + re.escape(wrong) + r'\b', right, text)
    return text

# %%
teencode_map = {}
with open("./vietnamese-teencode.txt", "r", encoding="utf8") as f:
    for line in f:
        parts = line.strip().split()
        if len(parts) >= 2:
            teencode_map[parts[0]] = parts[1]

# %%
import re

def remove_duplicate_emoji(text):
    # Xóa emoji trùng lặp liên tiếp (vd: 😄😄😄 -> 😄)
    emoji_pattern = re.compile(
        r'([\U0001F600-\U0001F64F\U0001F300-\U0001F5FF\U0001F680-\U0001F6FF\U0001F1E0-\U0001F1FF])\1+'
    )
    return emoji_pattern.sub(r'\1', text)

# %%
def preprocess_text(text, emoticon_dict, misspell_dict):
    text = str(text)
    text = standardize_emoticon(text)
    text = convert_emoticon(text, emoticon_dict)
    text = remove_duplicate_emoji(text)
    for abbr, full in teencode_map.items():
        pattern = rf"\b{re.escape(abbr)}\b"
        text = re.sub(pattern, full, text, flags=re.IGNORECASE)
    text = standardize_word(text, misspell_dict)
    return text

# %%
text = "ước gì sau này về già vẫn có thể như cụ này :)) :)))) :)))"
text = preprocess_text(text, emoticon_dict, misspell_dict)
print(text)
# Out:
# ước gì sau này về già vẫn có thể như cụ này ☺️ ☺️ ☺️

# %%
df_test['content_clean'] = df_test['content'].apply(lambda x: preprocess_text(x, emoticon_dict, misspell_dict))
df_test[['content', 'content_clean']].head(10)
# Out:
#                                              content  \
# 0                 Người ăn không hết kẻ lần chẳng ra
# 1    Nhiều người cứ nghĩ đạp xe là văn minh. haizzzz
# 2                                        Rất văn hoá
# 3  Đời ta ba mươi đời nó. Mua chiếc xe cũng chỉ p...
# 4  Tước bằng lái vĩnh viễn đi. Chạy lếu láo thật,...
# 5                                Cảm ơn các y bác sĩ
# 6                                    Thật tuyệt vời!
# 7  Quỷ dữ chứ không phải con người. Thật xót xa c...
# 8  Rất nguy hiểm nếu không quản lý tôt nguồn gốc ...
# 9  Nghe cũng nghẹn lòng thật, tương lai còn dài, ...
#
#                                        content_clean
# 0                 Người ăn không hết kẻ lần chẳng ra
# 1       Nhiều người cứ nghĩ đạp xe là văn minh. haiz
# 2                                        Rất văn hoá
# 3  Đời ta ba mươi đời nó. Mua chiếc xe z chỉ phục...
# 4  Tước bằng lái vĩnh viễn đi. Chạy lếu láo thật,...
# 5                                Cảm ơn các y bác sĩ
# 6                                    Thật tuyệt vời!
# 7  Quỷ dữ chứ không phải con người. Thật xót xa c...
# 8  Rất nguy hiểm nếu không quản lý tôt nguồn gốc ...
# 9  Nghe z nghẹn lòng thật, tương lai còn dài, lỡ ...

# %%
df_train['content_clean'] = df_train['content'].apply(lambda x: preprocess_text(x, emoticon_dict, misspell_dict))
df_train[['content', 'content_clean']].head(10)
# Out:
#                                              content  \
# 0                               Thật tuyệt vời...!!!
# 1  mỹ đã tuột dốc quá nhiều rồi, giờ muốn vực dậy...
# 2  tôi thấy người lái xe hơi bấm còi mới là người...
# 3  Coi dịch là giặc. Đã mang tên đó mà xâm nhập V...
# 4  Thương các bé quá! Các con còn quá nhỏ mà đã p...
# 5           Sevila đoạt cúp sau loạt đá luân lưu nha
# 6    Angelina Jolie có đôi bàn tay nổi gân guốc quá!
# 7  "Tôi không biết bà ấy làm thế nào để xử lý gã ...
# 8  tấm hình này chắc bộ nhớ máy tính chứa được 1 tấm
# 9                  Không trung sẽ không còn yên tĩnh
#
#                                        content_clean
# 0                               Thật tuyệt vời...!!!
# 1  mỹ đã tuột dốc quá nhiều rồi, giờ muốn vực dậy...
# 2  tôi thấy người lái xe hơi bấm còi mới là người...
# 3  Coi dịch là giặc. Đã mang tên đó mà xâm nhập v...
# 4  Thương các bé quá! Các con còn quá nhỏ mà đã p...
# 5           Sevila đoạt cúp sau loạt đá luân lưu nha
# 6    Angelina Jolie có đôi bàn tay nổi gân guốc quá!
# 7  "Tôi không biết bà ấy làm thế nào để xử lý gã ...
# 8  tấm hình này chắc bộ nhớ máy tính chứa được 1 tấm
# 9                  Không trung sẽ không còn yên tĩnh

# %%
df_dev['content_clean'] = df_dev['content'].apply(lambda x: preprocess_text(x, emoticon_dict, misspell_dict))
df_dev[['content', 'content_clean']].head(10)
# Out:
#                                              content  \
# 0  Cuộc bầu cư người đứng đầu Quốc gia ở Mỹ là cô...
# 1  Mình thích Messi ở lại để Barca và Cules hiểu ...
# 2             dám chui ra,vậy ăn vô lại ếch said :')
# 3  Hoan hô sự quả cảm của các chiến sĩ và sự đồng...
# 4  Tôi cực lực phản đối cho hs dùng đt trong lớp ...
# 5  Ta có công thức tính diện tích tam giác là (cạ...
# 6  Trước cũng thích con Seltos lắm nhưng giờ nhìn...
# 7  Chia không đều nhau, không công bằng thì rất d...
# 8                             nhìn logo thấy đẹp quá
# 9  Không mở đường bên Đồng Nai thì điểm kẹt nằm t...
#
#                                        content_clean
# 0  Cuộc bầu cư người đứng đầu Quốc gia ở Mỹ là cô...
# 1  Mình thích Messi ở lại để Barca và Cules hiểu ...
# 2               dám chui ra,vậy ăn vô lại ếch said 😂
# 3  Hoan hô sự quả cảm của các chiến sĩ và sự đồng...
# 4  Tôi cực lực phản đối cho hs dùng điện trong lớ...
# 5  Ta có công thức tính diện tích tam giác là (cạ...
# 6  Trước z thích con Seltos lắm nhưng giờ nhìn cá...
# 7  Chia không đều nhau, không công bằng thì rất d...
# 8                             nhìn logo thấy đẹp quá
# 9  Không mở đường bên Đồng Nai thì điểm kẹt nằm t...

# %%
df_train.to_csv("./df_train_clean.csv", index=False)
df_dev  .to_csv("./df_dev_clean.csv",   index=False)
df_test .to_csv("./df_test_clean.csv",  index=False)
print("Cleaned files written to /content/")
# Out:
# Cleaned files written to /content/

# %%
text = "dám chui ra,vậy ăn vô lại ếch said :')"
text = preprocess_text(text, emoticon_dict, misspell_dict)
print(text)
# Out:
# dám chui ra,vậy ăn vô lại ếch said 😂
